# %%
# import libraries
import json
import urllib.request, json 

# connect to DataCite REST API and get items with special ROR ID and type dataset
with urllib.request.urlopen('https://api.datacite.org/dois?query=creators.affiliation.affiliationIdentifier:"https://ror.org/051qn8h41"') as url:
    
    # create a json file out of API call
    DataCite = json.load(url)
    
    # print json in Jupyter Notebook
    print(DataCite)

# create and open a new json file    
with open('DataCite_Metadata_ROR051qn8h41.json', 'w') as f:
    # write results in json file
    json.dump(DataCite, f)
# Out:
# {'data': [{'id': '10.5061/dryad.0rxwdbs3r', 'type': 'dois', 'attributes': {'doi': '10.5061/dryad.0rxwdbs3r', 'identifiers': [], 'creators': [{'name': 'Del Rio, Miren', 'nameType': 'Personal', 'givenName': 'Miren', 'familyName': 'Del Rio', 'affiliation': ['Instituto Nacional de Investigación y Tecnología Agraria y Alimentaria'], 'nameIdentifiers': [{'schemeUri': 'https://orcid.org', 'nameIdentifier': 'https://orcid.org/0000-0001-7496-3713', 'nameIdentifierScheme': 'ORCID'}]}, {'name': 'Ruiz‐Peinado, Ricardo', 'nameType': 'Personal', 'givenName': 'Ricardo', 'familyName': 'Ruiz‐Peinado', 'affiliation': ['Instituto Nacional de Investigación y Tecnología Agraria y Alimentaria'], 'nameIdentifiers': []}, {'name': 'Holm, Stig‐Olof', 'nameType': 'Personal', 'givenName': 'Stig‐Olof', 'familyName': 'Holm', 'affiliation': ['Umeå University'], 'nameIdentifiers': []}, {'name': 'Jansons, Aris', 'nameType': 'Personal', 'givenName': 'Aris', 'familyName': 'Jansons', 'affiliation': ['Latvian State Forest Research Institute "Silava"'], 'nameIdentifiers': []}, {'name': 'Nord‐Larsen, Thomas', 'nameType': 'Personal', 'givenName': 'Thomas', 'familyName': 'Nord‐Larsen', 'affiliation': ['University of Copenhagen'], 'nameIdentifiers': []}, {'name': 'Verheyen, Kris', 'nameType': 'Personal', 'givenName': 'Kris', 'familyName': 'Verheyen', 'affiliation': ['Ghent University'], 'nameIdentifiers': [{'schemeUri': 'https://orcid.org', 'nameIdentifier': 'https://orcid.org/0000-0002-2067-9108', 'nameIdentifierScheme': 'ORCID'}]}, {'name': 'Bravo‐Oviedo, Andrés', 'nameType': 'Personal', 'givenName': 'Andrés', 'familyName': 'Bravo‐Oviedo', 'affiliation': ['Spanish National Research Council'], 'nameIdentifiers': [{'schemeUri': 'https://orcid.org', 'nameIdentifier': 'https://orcid.org/0000-0001-7036-7041', 'nameIdentifierScheme': 'ORCID'}]}, {'name': 'Pretzsch, Hans', 'nameType': 'Personal', 'givenName': 'Hans', 'familyName': 'Pretzsch', 'affiliation': ['Technical University Munich'], 'nameIdentifiers': [{'schemeUri': 'https://orcid.org', 'nameIdentifier': 'https://orcid.org/0000-0002-4958-1868', 'nameIdentifierScheme': 'ORCID'}]}, {'name': 'Ruiz-Peinado, Ricardo', 'nameType': 'Personal', 'givenName': 'Ricardo', 'familyName': 'Ruiz-Peinado', 'affiliation': ['Instituto Nacional de Investigación y Tecnología Agraria y Alimentaria'], 'nameIdentifiers': []}, {'name': 'Jactel, Hervé', 'nameType': 'Personal', 'givenName': 'Hervé', 'familyName': 'Jactel', 'affiliation': ['University of Bordeaux'], 'nameIdentifiers': [{'schemeUri': 'https://orcid.org', 'nameIdentifier': 'https://orcid.org/0000-0002-8106-5310', 'nameIdentifierScheme': 'ORCID'}]}, {'name': 'Coll, Lluís', 'nameType': 'Personal', 'givenName': 'Lluís', 'familyName': 'Coll', 'affiliation': ['University of Lleida'], 'nameIdentifiers': []}, {'name': 'Löf, Magnus', 'nameType': 'Personal', 'givenName': 'Magnus', 'familyName': 'Löf', 'affiliation': ['Swedish University of Agricultural Sciences'], 'nameIdentifiers': []}, {'name': 'Aldea, Jorge', 'nameType': 'Personal', 'givenName': 'Jorge', 'familyName': 'Aldea', 'affiliation': ['Swedish University of Agricultural Sciences'], 'nameIdentifiers': [{'schemeUri': 'https://orcid.org', 'nameIdentifier': 'https://orcid.org/0000-0003-2568-5192', 'nameIdentifierScheme': 'ORCID'}]}, {'name': 'Ammer, Christian', 'nameType': 'Personal', 'givenName': 'Christian', 'familyName': 'Ammer', 'affiliation': ['University of Göttingen'], 'nameIdentifiers': []}, {'name': 'Avdagić, Admir', 'nameType': 'Personal', 'givenName': 'Admir', 'familyName': 'Avdagić', 'affiliation': ['University of Sarajevo'], 'nameIdentifiers': []}, {'name': 'Barbeito, Ignacio', 'nameType': 'Personal', 'givenName': 'Ignacio', 'familyName': 'Barbeito', 'affiliation': ['University of British Columbia'], 'nameIdentifiers': []}, {'name': 'Bielak, Kamil', 'nameType': 'Personal', 'givenName': 'Kamil', 'familyName': 'Bielak', 'affiliation': ['Warsaw University of Life Sciences'], 'nameIdentifiers': []}, {'name': 'Bravo, Felip ...
